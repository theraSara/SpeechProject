# %% [markdown]
# # Official-split analysis of classical baselines
#
# This notebook summarizes the official-split results for the two classical baselines used in the project:
#
# - **MFCC + DTW**
# - **MFCC + HMM-GMM**
#
# The evaluation follows the shared 5-shot and 10-shot episodic splits and reports the agreed operating-point metrics:
#
# - **ACC+@5% FAR**
# - **AUROC**
# - **FRR+@5% FAR**
#
# The focus is on concise figures that can be reused in the individual portfolio report and the group report.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path
outdir = Path('.')
summary_df = pd.read_csv('results/baseline_results_table.csv')
per_trial_df = pd.read_csv('official_per_trial_metrics.csv')
summary_df[['method','acc_plus_5','auroc','frr_plus_5','far_at_5','mean_inference_time_ms']]
# Out:
#                    method  acc_plus_5     auroc  frr_plus_5  far_at_5  \
# 0       MFCC+DTW (5-shot)    0.060334  0.610260    0.895631  0.049725
# 1   MFCC+HMM-GMM (5-shot)    0.115709  0.659251    0.800025  0.049814
# 2      MFCC+DTW (10-shot)    0.062150  0.622400    0.895484  0.049814
# 3  MFCC+HMM-GMM (10-shot)    0.220938  0.726121    0.693029  0.047465
#
#    mean_inference_time_ms
# 0               22.170162
# 1                8.450389
# 2               45.352983
# 3                6.593633

# %% [markdown]
# ## Main observations
#
# 1. **HMM-GMM consistently outperforms DTW** under the official fixed-FAR evaluation.
# 2. The best overall baseline is **MFCC+HMM-GMM (10-shot)** with:
#    - ACC+@5% = **22.09%**
#    - AUROC = **0.726**
#    - FRR+@5% = **69.30%**
# 3. DTW shows **very small gains from 5-shot to 10-shot**, while latency and storage roughly double.
# 4. HMM-GMM benefits substantially from 10-shot enrollment and is also **faster and smaller** than DTW in this implementation.

# %%
from PIL import Image

img = Image.open("./results/roc_comparison.png")
plt.imshow(img)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(1035.5), np.float64(816.5), np.float64(-0.5))

# %%
img = Image.open("./results/cm_MFCC+HMM-GMM_(10-shot).png")
plt.imshow(img)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(1383.5), np.float64(1278.5), np.float64(-0.5))

# %%
img = Image.open("./results/dist_MFCC+DTW_(5-shot).png")
plt.imshow(img)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(1280.5), np.float64(700.5), np.float64(-0.5))
